# %%
idades = [15,32,32,37,49,56,65,87]

# %%
sorted(idades)
# Out:
# [15, 32, 32, 37, 49, 56, 65, 87]

# %%
sorted(idades, reverse=True)
# Out:
# [87, 65, 56, 49, 37, 32, 32, 15]

# %%
nova_lista = list(reversed(idades))

# %%
list(reversed(idades))
# Out:
# [87, 65, 56, 49, 37, 32, 32, 15]

# %%
idades.sort()

# %%
idades
# Out:
# [15, 32, 32, 37, 49, 56, 65, 87]
